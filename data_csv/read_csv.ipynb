# %%
import pandas as pd
import numpy as np

# %%
# Load the data
data = pd.read_csv('comments.csv')
data
# Out:
#         authorDisplayName           publishedAt  likeCount  \
# 0        @sergioelian6557  2024-02-05T01:12:16Z          0
# 1        @jhonsanchez4448  2024-02-03T17:09:02Z          0
# 2              @Motas3110  2024-02-02T23:30:58Z          1
# 3         @samuelrico8715  2024-02-02T06:42:32Z          0
# 4              @megasirob  2024-02-01T21:35:54Z          0
# ..                    ...                   ...        ...
# 116      @user-hu5se6cq7v  2024-01-25T21:09:52Z          3
# 117         @JouseMarquez  2024-01-25T21:08:40Z          1
# 118  @sebastianmorales823  2024-01-25T21:08:14Z          2
# 119      @nahuelllamas709  2024-01-25T21:07:52Z          2
# 120            @omega_dev  2024-01-25T21:07:46Z          1
#
#                                           textOriginal  \
# 0                          Gracias por el curso crack!
# 1             Como siempre, excelente …. Gracias crack
# 2    Definitivamente si no aprende AWS aca, me dedi...
# ...

# %%
data2 = pd.read_csv('transcript.csv')
data2
# Out:
#                                           text  \
# 0       aws Amazon web Services que me imagino
# 1        que muchos de ustedes conocerán ahora
# 2         hablaremos un poquito de esto de aws
# 3     porque hoy vamos a hacer el curso de aws
# 4      del Cloud vamos a ver un poquito de los
# ...                                        ...
# 3152      que es bastante interesante al menos
# 3153      pues mejorar este tipo de cosas vale
# 3154        mira y si sigues influencer de aws
# 3155  suelen poner links con descuento del 50%
# 3156         bu Pues mira bastante interesante
#
#                          textPreprocess  \
# 0       aws amazon web services imagino
# 1               ustedes conocerán ahora
# 2                hablaremos poquito aws
# 3             hoy vamos hacer curso aws
# 4               cloud vamos ver poquito
# ...                                 ...
# 3152         bastante interesante menos
# 3153       pues mejorar tipo cosas vale
# ...
