# %%
import pandas as pd
import numpy as np

# %%
# Load the data
data = pd.read_csv('comments.csv')
data
# Out:
#      Unnamed: 0                authorDisplayName           publishedAt  \
# 0             0                         @elssy72  2024-02-11T03:28:39Z
# 1             1                    @the_king5702  2024-02-11T03:10:05Z
# 2             2               @alexfernandez4196  2024-02-11T03:07:54Z
# 3             3                 @user-zw9mx5xn3j  2024-02-11T02:43:01Z
# 4             4                 @wendyfierro4304  2024-02-11T02:32:37Z
# ..          ...                              ...                   ...
# 186         186              @stevenpalacios8519  2024-02-07T15:02:17Z
# 187         187            @shelomitcastillo1910  2024-02-07T15:02:06Z
# 188         188                    @jersontellez  2024-02-07T15:01:50Z
# 189         189  @sandramilenalagunabarragan2372  2024-02-07T14:36:30Z
# 190         190                      @milaptopsv  2024-02-07T14:35:32Z
#
#      likeCount                                       textOriginal  \
# ...

# %%
data2 = pd.read_csv('transcript.csv')
data2
# Out:
#      Unnamed: 0                                  text  \
# 0             0                              [Música]
# 1             1         El Salvador ha roto todos los
# 2             2  récords este día El Salvador ha roto
# 3             3        todos los récords de todas las
# 4             4   democracias en toda la historia del
# ..          ...                                   ...
# 458         458  Seguiremos demostrándole al mundo el
# 459         459                           ejemplo del
# 460         460                              Salvador
# 461         461                              y muchas
# 462         462                               gracias
#
#                      textPreprocess emotion
# 0                            música  others
# 1                     salvador roto  others
# 2         récords día salvador roto     joy
# 3                     récords todas     joy
# 4         democracias toda historia  others
# ..                              ...     ...
# ...
